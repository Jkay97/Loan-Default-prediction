# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = pd.read_csv("Lending Club 2016_2018.csv")
df.head()
# Out:
#           id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0  130956066     3000.0       3000.0           3000.0   36 months      7.34
# 1  130968727     5000.0       5000.0           5000.0   36 months     11.98
# 2  130910225     7000.0       7000.0           7000.0   36 months     11.98
# 3  130966492    30000.0      30000.0          30000.0   36 months     21.85
# 4  130942737    21000.0      21000.0          21000.0   60 months     20.39
#
#    installment grade emp_length home_ownership  ...   issue_d  \
# 0        93.10     A    9 years           RENT  ...  Mar-2018
# 1       166.03     B  10+ years            OWN  ...  Mar-2018
# 2       232.44     B   < 1 year       MORTGAGE  ...  Mar-2018
# 3      1143.39     D  10+ years            OWN  ...  Mar-2018
# 4       560.94     D  10+ years            OWN  ...  Mar-2018
#
#   chargeoff_within_12_mths acc_now_delinq mort_acc  mths_since_recent_bc_dlq  \
# 0                      0.0            0.0      4.0                       NaN
# 1                      0.0            0.0      0.0                       NaN
# 2                      0.0            0.0      0.0                      64.0
# 3                      0.0            0.0      2.0                       NaN
# 4                      0.0            0.0      3.0                       NaN
#
#    num_accts_ever_120_pd  pct_tl_nvr_dlq  pub_rec_bankruptcies  \
# 0                    0.0            96.7                   0.0
# 1                    1.0            95.7                   1.0
# 2                    3.0            89.7                   0.0
# 3                    1.0            96.0                   0.0
# 4                    0.0            92.6                   0.0
#
#    tot_hi_cred_lim  loan_status
# 0         191216.0            0
# 1          61551.0            0
# 2         132817.0            0
# 3         188780.0            0
# 4         172433.0            0
#
# [5 rows x 39 columns]

# %%
df.shape
# Out:
# (518706, 39)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518706 entries, 0 to 518705
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           518706 non-null  int64
#  1   loan_amnt                    518706 non-null  float64
#  2   funded_amnt                  518706 non-null  float64
#  3   funded_amnt_inv              518706 non-null  float64
#  4   term                         518706 non-null  object
#  5   int_rate                     518706 non-null  float64
#  6   installment                  518706 non-null  float64
#  7   grade                        518706 non-null  object
#  8   emp_length                   482772 non-null  object
#  9   home_ownership               518706 non-null  object
#  10  annual_inc                   518706 non-null  float64
#  11  verification_status          518706 non-null  object
#  12  purpose                      518706 non-null  object
#  13  addr_state                   518706 non-null  object
#  14  dti                          518334 non-null  float64
#  15  delinq_2yrs                  518706 non-null  float64
#  16  inq_last_6mths               518705 non-null  float64
#  17  mths_since_last_delinq       264252 non-null  float64
#  18  mths_since_last_record       99889 non-null   float64
#  19  open_acc                     518706 non-null  float64
#  20  pub_rec                      518706 non-null  float64
#  21  revol_bal                    518706 non-null  float64
#  22  revol_util                   518293 non-null  float64
#  23  total_acc                    518706 non-null  float64
#  24  initial_list_status          518706 non-null  object
#  25  collections_12_mths_ex_med   518706 non-null  float64
#  26  mths_since_last_major_derog  146471 non-null  float64
#  27  tot_coll_amt                 518706 non-null  float64
#  28  tot_cur_bal                  518706 non-null  float64
#  29  issue_d                      518706 non-null  object
#  30  chargeoff_within_12_mths     518706 non-null  float64
#  31  acc_now_delinq               518706 non-null  float64
#  32  mort_acc                     518706 non-null  float64
#  33  mths_since_recent_bc_dlq     125764 non-null  float64
#  34  num_accts_ever_120_pd        518706 non-null  float64
#  35  pct_tl_nvr_dlq               518705 non-null  float64
#  36  pub_rec_bankruptcies         518706 non-null  float64
#  37  tot_hi_cred_lim              518706 non-null  float64
#  38  loan_status                  518706 non-null  int64
# dtypes: float64(28), int64(2), object(9)
# memory usage: 154.3+ MB

# %%
ncols = ['loan_amnt',
         'funded_amnt',
         'funded_amnt_inv',
         'int_rate',
         'installment',
         'annual_inc',
         'dti','tot_cur_bal',
         'delinq_2yrs',
         'inq_last_6mths',
         'mths_since_last_delinq',
         'mths_since_last_major_derog',
         'mths_since_last_record',
         'open_acc','pub_rec',
         'revol_bal','revol_util',
         'total_acc',
         'collections_12_mths_ex_med',
         'tot_coll_amt',
         'chargeoff_within_12_mths',
         'mths_since_recent_bc_dlq', 
         'pct_tl_nvr_dlq',
         'pub_rec_bankruptcies']

# %%
plt.figure(figsize = (20,30))

for i in range(1,len(ncols)+1):
    plt.subplot(8,3,i)
    sns.violinplot(x=df['loan_status'],y= df[ncols[i-1]])
#     sns.distplot(df[num_cols[i-1]])
    
plt.show()
